# %%
import numpy as np
l1 = [1,2,3]

l2 = [[1,2,3],
     [11,22,33]]

l3 = [[[1,2,3]]]

# %%
array1 = np.array(l1)

print('array1 type:', type(array1))
print('array1 array 형태:', array1.shape) # 튜플의 법칙때문에~ (3,)
# Out:
# array1 type: <class 'numpy.ndarray'>
# array1 array 형태: (3,)

# %%
array2 = np.array(l2)

print('array2 type:', type(array2))
print('array2 array 형태:', array2.shape)
# Out:
# array2 type: <class 'numpy.ndarray'>
# array2 array 형태: (2, 3)

# %%
array3 = np.array(l3)

print('array3 type:', type(array3))
print('array3 array 형태:', array3.shape)
# Out:
# array3 type: <class 'numpy.ndarray'>
# array3 array 형태: (1, 1, 3)

# %%
### 각 array의 차원을 살펴보면, 
print('array1:{0}차원, array2:{1}차원, array3:{2}차원'.format(array1.ndim,
                                                       array2.ndim,
                                                       array3.ndim)) # property
# Out:
# array1:1차원, array2:2차원, array3:3차원

# %% [markdown]
# ### array의 데이터 자료 확인

# %%
list1 = [1,2,'test']
array2 = np.array(list1)
print(array2, array2.dtype)

list2 = [1,2,3.4]
array3 = np.array(list2)
print(array3, array3.dtype)
# Out:
# ['1' '2' 'test'] <U11
# [1.  2.  3.4] float64

# %% [markdown]
# ### 각 자료들의 float 및 int 변환

# %%
array_int = np.array([1,2,3])

# 위의 array_int의 자료를 float으로 변환
array_float = array_int.astype('float64')
print(array_float, array_float.dtype)

# array_float -> array_int1 데이터 변환
array_int1 = array_float.astype('int32')
print(array_int1, array_int1.dtype)

# 과연 실수데이터를 int로 변환시킬때 소수점 뒤의 자리는?
array_float1 = np.array([1.1, 2.3, 4.4])
array_int2 = array_float1.astype('int32')
print(array_int2, array_int2.dtype)
# Out:
# [1. 2. 3.] float64
# [1 2 3] int32
# [1 2 4] int32

# %% [markdown]
# ### ndarray를 편리하게 생성 - arange, zeros, ones

# %%
sq_array = np.arange(6,10)
print(sq_array)
print(sq_array.dtype, sq_array.shape)
# Out:
# [6 7 8 9]
# int32 (4,)

# %%
zero_array = np.zeros((3,2), dtype='float64')
print(zero_array)
print(zero_array.dtype, zero_array.shape)
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]]
# float64 (3, 2)

# %%
one_array = np.ones((3,2), dtype = 'int32')
print(one_array)
print(one_array.dtype, one_array.shape)
# Out:
# [[1 1]
#  [1 1]
#  [1 1]]
# int32 (3, 2)

# %%
#Q1-1 titanic_train 데이터 로드
import pandas as pd
pd.read_csv('D:/Tigro_Park/22.05.26/train.csv') # 절대경로
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# #Q1-2 titanic_train 데이터 로드
# import pandas as pd
pd.read_csv(r'D:\Tigro_Park\22.05.26\train.csv') # 절대경로
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Q1-3 titanic_train 데이터 로드
import pandas as pd
titan_df = pd.read_csv('./test/train.csv') # 상대경로 
titan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Q2 jeju.csv 데이터 로드
import pandas as pd
pd.read_csv('./test/jeju.csv')
# Out:
#       Unnamed: 0     id          일자   시도명  읍면동명         거주인구       근무인구  \
# 0              0  22448  2018-01-01   제주시   도두동    32249.987   3418.266
# 1              1  22449  2018-01-01   제주시   외도동   213500.997  10341.172
# 2              2  22450  2018-01-01   제주시  이도2동  1212382.218  96920.834
# 3              3  22451  2018-01-01   제주시  일도1동    33991.653   6034.253
# 4              4  22452  2018-01-01  서귀포시   대천동   155036.925   9403.969
# ...          ...    ...         ...   ...   ...          ...        ...
# 9616        9616  32064  2020-04-30  서귀포시   표선면   228260.005  16891.732
# 9617        9617  32065  2020-04-30   제주시   한림읍   459959.064  26007.122
# 9618        9618  32066  2020-04-30   제주시   도두동    28397.481   3144.895
# 9619        9619  32067  2020-04-30  서귀포시   안덕면   348037.846  29106.286
# 9620        9620  32068  2020-04-30   제주시    연동  1010643.372  65673.477
#
#             방문인구       총 유동인구   평균 속도  평균 소요 시간  평균 기온  일강수량  평균 풍속
# ...

# %%
#Q3 chipotle.csv 데이터 로드
import pandas as pd
pd.read_csv('./test/chipotle.csv')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# end of file

# %%
|
